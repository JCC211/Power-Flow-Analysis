# %%
import numpy as np
from sympy import symbols,diff,sin,cos,Matrix,hessian
import matplotlib.pyplot as plt

# %%
theta2_true = np.deg2rad(-2.07) # rad
theta3_true = np.deg2rad(-8.79) # rad
voltage3_true = 0.9781 # pu
def PCE(act,exp):
    pce = abs((act-exp)/exp)*100
    return pce

# %% [markdown]
# ## Power Flow Analysis Using Newton-Raphson Method

# %%
# calculate J
# admittance matrix
Y = Matrix([[-36.92,21.097,15.823],[21.097,-42.194,21.097],[15.823,21.097,-36.92]])
# known variables
v1 = 1
t1 = 0
v2 = 1.05
p2 = 2
p3 = -5
q3 = -1
# power flow equations
t2, t3, v3 = symbols('t2 t3 v3', real=True)
sym = Matrix([t2,t3,v3])
fp2 = (v2*v1*Y[1,0]*sin(t2-t1))+(v2*v3*Y[1,2]*sin(t2-t3))-2
fp3 = (v3*v1*Y[2,0]*sin(t3-t1))+(v3*v2*Y[2,1]*sin(t3-t2))+5
fq3 = (-Y[2,2]*(v3**2))-(v3*v1*Y[2,0]*cos(t3-t1))-(v3*v2*Y[2,1]*cos(t3-t2))+1
X = Matrix([[fp2],[fp3],[fq3]])
# J
J = X.jacobian(sym)
print(f"Jacobian Matrix: {J.shape}")
print(f"{J[0,0]}\n{J[0,1]}\n{J[0,2]}")
print(f"{J[1,0]}\n{J[1,1]}\n{J[1,2]}")
print(f"{J[2,0]}\n{J[2,1]}\n{J[2,2]}")
# Out:
# Jacobian Matrix: (3, 3)
# 22.15185*v3*cos(t2 - t3) + 22.15185*cos(t2)
# -22.15185*v3*cos(t2 - t3)
# 22.15185*sin(t2 - t3)
# -22.15185*v3*cos(t2 - t3)
# 15.823*v3*cos(t3) + 22.15185*v3*cos(t2 - t3)
# 15.823*sin(t3) - 22.15185*sin(t2 - t3)
# 22.15185*v3*sin(t2 - t3)
# 15.823*v3*sin(t3) - 22.15185*v3*sin(t2 - t3)
# 73.84*v3 - 15.823*cos(t3) - 22.15185*cos(t2 - t3)

# %%
# plot arrays
NR_iteration = []
NR_theta2 = []
NR_theta3 = []
NR_voltage3 = []
NR_t2error = []
NR_t3error = []
NR_v3error = []
# admittance matrix
Y = Matrix([[-36.92,21.097,15.823],[21.097,-42.194,21.097],[15.823,21.097,-36.92]])
# known variables
v1 = 1
t1 = 0
v2 = 1.05
p2 = 2
p3 = -5
q3 = -1
# unknown variables / initial guesses
t2 = 0
t3 = 0
v3 = 1
NR_iteration.append(0)
NR_theta2.append(t2)
NR_theta3.append(t3)
NR_voltage3.append(v3)
NR_t2error.append(1)
NR_t3error.append(1)
NR_v3error.append(1)
# parameters
max_iter = 100
threshold = 0.0001
i = 0
done = False
fx = Matrix([[1],[1],[1]])

# perform N-R analysis
while not done:
    i += 1
    # define f(x), J(x), xnew
    x = Matrix([[t2],[t3],[v3]])
    # print(x.shape,x)
    fx = Matrix([[(v2*v1*Y[1,0]*sin(t2-t1))+(v2*v3*Y[1,2]*sin(t2-t3))-2],\
                   [(v3*v1*Y[2,0]*sin(t3-t1))+(v3*v2*Y[2,1]*sin(t3-t2))+5],\
                   [(-Y[2,2]*(v3**2))-(v3*v1*Y[2,0]*cos(t3-t1))-(v3*v2*Y[2,1]*cos(t3-t2))+1]])
    # print(fx.shape,fx)
    J = Matrix([[22.15185*v3*cos(t2-t3)+22.15185*cos(t2),-22.15185*v3*cos(t2-t3),22.15185*sin(t2-t3)],\
                  [-22.15185*v3*cos(t2-t3),15.823*v3*cos(t3)+22.15185*v3*cos(t2-t3),\
                   15.823*sin(t3)-22.15185*sin(t2-t3)],\
                  [22.15185*v3*sin(t2-t3),15.823*v3*sin(t3)-22.15185*v3*sin(t2-t3),\
                   73.84*v3-15.823*cos(t3)-22.15185*cos(t2-t3)]])
    # print(J.shape,J)
    Jinv = J.inv()
    xn = x - np.matmul(Jinv,fx)

    print(f"\nIteration: {i}")
    print(f"x = {x}\nfx = {fx}\nJ = {J}")
    print(f"xn = {xn}")
    
    # update values of x for next iteration
    t2 = xn[0,0]
    t3 = xn[1,0]
    v3 = xn[2,0]
    # update plot arrays and update i
    NR_iteration.append(i)
    NR_theta2.append(t2)
    NR_theta3.append(t3)
    NR_voltage3.append(v3)
    NR_t2error.append(fx[0,0])
    NR_t3error.append(fx[1,0])
    NR_v3error.append(fx[2,0])
    if (abs(fx[0,0])<threshold) and (abs(fx[1,0])<threshold) and (abs(fx[2,0])<threshold):
        print(f"\nERROR CRITERIA MET AFTER {i} ITERATIONS")
        done = True
    if i >= max_iter:
        break
print(f"\nFinal Results:\nTheta 2 = {t2} rad | Theta 3 = {t3} rad | Voltage 3 = {v3} p.u.")
print(f"Percent Error:\nTheta 2: {PCE(t2,theta2_true)} % | Theta 3: {PCE(t3,theta3_true)} % | Voltage 3 {PCE(v3,voltage3_true)} %")
# Out:
# Iteration: 1
# x = Matrix([[0], [0], [1]])
# fx = Matrix([[-2], [5], [-0.0548500000000018]])
# J = Matrix([[44.3037000000000, -22.1518500000000, 0], [-22.1518500000000, 37.9748500000000, 0], [0, 0, 35.8651500000000]])
# xn = Matrix([[-0.0292094572543390], [-0.148704827423401], [1.00152933976297]])
#
# Iteration: 2
# x = Matrix([[-0.0292094572543390], [-0.148704827423401], [1.00152933976297]])
# fx = Matrix([[-0.00216448317800921], [0.00733355304470784], [0.333187461691534]])
# J = Matrix([[44.1699202782023, -22.0275195012964, 2.64074842608688], [-22.0275195012964, 37.6998253378601, -4.98504262305174], [2.64478702765890, -4.99266644695529, 36.3106689114567]])
# xn = Matrix([[-0.0293586524927519], [-0.150226090883588], [0.992155014163930]])
#
# Iteration: 3
# x = Matrix([[-0.0293586524927519], [-0.150226090883588], [0.992155014163930]])
# fx = Matrix([[-0.000285358419734427], [0.000511224725157078], [0.00321556024254477]])
# J = Matrix([[43.9600302843360, -21.8177262759509, 2.67092303938072], [-21.8177262759509, 37.3397828828203, -5.03901981434606], [2.64996968596755, -4.99948877527484, 35.6256970923953]])
# xn = Matrix([[-0.0293599033551881], [-0.150253194217700], [0.992061044120313]])
#
# Iteration: 4
# x = Matrix([[-0.0293599033551881], [-0.150253194217700], [0.992061044120313]])
# fx = Matrix([[-5.43071863035038e-8], [9.50163716595398e-8], [3.26488159174687e-7]])
# J = Matrix([[43.9578945381164, -21.8155913431282, 2.67149154052914], [-21.8155913431282, 37.3361141289511, -5.04001234058864], [2.65028268705592, -4.99999990498363, 35.6188915907498]])
# xn = Matrix([[-0.0293599034790353], [-0.150253198145482], [0.992061034412014]])
#
# ERROR CRITERIA MET AFTER 4 ITERATIONS
#
# Final Results:
# Theta 2 = -0.0293599034790353 rad | Theta 3 = -0.150253198145482 rad | Voltage 3 = 0.992061034412014 p.u.
# Percent Error:
# Theta 2: 18.7343692627929 % | Theta 3: 2.06059030626813 % | Voltage 3 1.42736268398056 %

# %%
plt.subplot(2,2,1,title='Theta 2',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(NR_iteration,NR_theta2)
plt.subplot(2,2,2,title='Theta 3',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(NR_iteration,NR_theta3)
plt.subplot(2,2,3,title='Voltage 3',xlabel='Iteration',ylabel='Voltage (p.u.)')
plt.plot(NR_iteration,NR_voltage3)
plt.subplot(2,2,4,title='Error',xlabel='Iteration',ylabel='Error')
plt.plot(NR_iteration,NR_t2error,NR_iteration,NR_t3error,NR_iteration,NR_v3error)
plt.legend(['Theta 2','Theta 3','Voltage 3'],loc=1)
plt.tight_layout()

# %% [markdown]
# ## Power Flow Analysis Using Modified Newton-Raphson Method

# %%
# calculate H
Y = np.array([[-36.92,21.097,15.823],[21.097,-42.194,21.097],[15.823,21.097,-36.92]])
# known variables
v1 = 1
t1 = 0
v2 = 1.05
p2 = 2
p3 = -5
q3 = -1
# power flow equations
t2, t3, v3 = symbols('t2 t3 v3')
sym = [t2,t3,v3]
p2c = v2*v1*Y[1,0]*sin(t2-t1) + v2*v3*Y[1,2]*sin(t2-t3) - 2
p3c = v3*v1*Y[2,0]*sin(t3-t1) + v3*v2*Y[2,1]*sin(t3-t2) + 5
q3c = -Y[2,2]*v3**2 - v3*v1*Y[2,0]*cos(t3-t1) - v3*v2*Y[2,1]*cos(t3-t2) + 1
# H
combined_expression = p2c + p3c + q3c
hessian_matrix = hessian(combined_expression,sym)
print(f"Hessian Matrix: {hessian_matrix.shape}")
print(f"{hessian_matrix[0,0]}\n{hessian_matrix[0,1]}\n{hessian_matrix[0,2]}")
print(f"{hessian_matrix[1,0]}\n{hessian_matrix[1,1]}\n{hessian_matrix[1,2]}")
print(f"{hessian_matrix[2,0]}\n{hessian_matrix[2,1]}\n{hessian_matrix[2,2]}")
# Out:
# Hessian Matrix: (3, 3)
# 22.15185*v3*cos(t2 - t3) - 22.15185*sin(t2)
# -22.15185*v3*cos(t2 - t3)
# 22.15185*sin(t2 - t3)
# -22.15185*v3*cos(t2 - t3)
# -15.823*v3*sin(t3) + 15.823*v3*cos(t3) + 22.15185*v3*cos(t2 - t3)
# 15.823*sin(t3) - 22.15185*sin(t2 - t3) + 15.823*cos(t3)
# 22.15185*sin(t2 - t3)
# 15.823*sin(t3) - 22.15185*sin(t2 - t3) + 15.823*cos(t3)
# 73.8400000000000

# %%
# plot arrays
MNR_iteration = []
MNR_theta2 = []
MNR_theta3 = []
MNR_voltage3 = []
MNR_t2error = []
MNR_t3error = []
MNR_v3error = []
# admittance matrix
Y = Matrix([[-36.92,21.097,15.823],[21.097,-42.194,21.097],[15.823,21.097,-36.92]])
# known variables
v1 = 1
t1 = 0
v2 = 1.05
p2 = 2
p3 = -5
q3 = -1
# unknown variables / initial guesses
t2 = 0
t3 = 0
v3 = 1
MNR_iteration.append(0)
MNR_theta2.append(t2)
MNR_theta3.append(t3)
MNR_voltage3.append(v3)
MNR_t2error.append(1)
MNR_t3error.append(1)
MNR_v3error.append(1)
# parameters
max_iter = 100
threshold = 0.0001
i = 0
done = False
fx = Matrix([[1],[1],[1]])
alpha = 0.1

# perform N-R analysis
while not done:
    i += 1
    # define f(x), J(x), xnew, and H
    x = Matrix([[t2],[t3],[v3]])
    # print(x.shape,x)
    fx = Matrix([[(v2*v1*Y[1,0]*sin(t2-t1))+(v2*v3*Y[1,2]*sin(t2-t3))-2],\
                   [(v3*v1*Y[2,0]*sin(t3-t1))+(v3*v2*Y[2,1]*sin(t3-t2))+5],\
                   [(-Y[2,2]*(v3**2))-(v3*v1*Y[2,0]*cos(t3-t1))-(v3*v2*Y[2,1]*cos(t3-t2))+1]])
    # print(fx.shape,fx)
    J = Matrix([[22.15185*v3*cos(t2-t3)+22.15185*cos(t2),-22.15185*v3*cos(t2-t3),22.15185*sin(t2-t3)],\
                  [-22.15185*v3*cos(t2-t3),15.823*v3*cos(t3)+22.15185*v3*cos(t2-t3),\
                   15.823*sin(t3)-22.15185*sin(t2-t3)],\
                  [22.15185*v3*sin(t2-t3),15.823*v3*sin(t3)-22.15185*v3*sin(t2-t3),\
                   73.84*v3-15.823*cos(t3)-22.15185*cos(t2-t3)]])
    # print(J.shape,J)
    H = Matrix([[22.15185*v3*cos(t2-t3)-22.15185*sin(t2),-22.15185*v3*cos(t2-t3),22.15185*sin(t2-t3)],\
           [-22.15185*v3*cos(t2-t3),-15.823*v3*sin(t3)+15.823*v3*cos(t3)+22.15185*v3*cos(t2-t3),\
            15.823*sin(t3)-22.15185*sin(t2-t3)+15.823*cos(t3)],\
           [22.15185*sin(t2-t3),15.823*sin(t3)-22.15185*sin(t2-t3)+15.823*cos(t3),73.8400000000000]])
    
    xn = x - np.matmul((J-(alpha*H)).inv(),fx)

    print(f"\nIteration: {i}")
    print(f"x = {x}\nfx = {fx}\nJ = {J}\nH = {H}")
    print(f"xn = {xn}")
    
    # update values of x for next iteration
    t2 = xn[0,0]
    t3 = xn[1,0]
    v3 = xn[2,0]
    # update plot arrays and update i
    MNR_iteration.append(i)
    MNR_theta2.append(t2)
    MNR_theta3.append(t3)
    MNR_voltage3.append(v3)
    MNR_t2error.append(fx[0,0])
    MNR_t3error.append(fx[1,0])
    MNR_v3error.append(fx[2,0])
    if (abs(fx[0,0])<threshold) and (abs(fx[1,0])<threshold) and (abs(fx[2,0])<threshold):
        print(f"\nERROR CRITERIA MET AFTER {i} ITERATIONS")
        done = True
    if i >= max_iter:
        break
print(f"\nFinal Results:\nTheta 2 = {t2} rad | Theta 3 = {t3} rad | Voltage 3 = {v3} p.u.")
print(f"Percent Error:\nTheta 2: {PCE(t2,theta2_true)}% | Theta 3: {PCE(t3,theta3_true)}% | Voltage 3: {PCE(v3,voltage3_true)}%")
# Out:
# Iteration: 1
# x = Matrix([[0], [0], [1]])
# fx = Matrix([[-2], [5], [-0.0548500000000018]])
# J = Matrix([[44.3037000000000, -22.1518500000000, 0], [-22.1518500000000, 37.9748500000000, 0], [0, 0, 35.8651500000000]])
# H = Matrix([[22.1518500000000, -22.1518500000000, 0], [-22.1518500000000, 37.9748500000000, 15.8230000000000], [0, 15.8230000000000, 73.8400000000000]])
# xn = Matrix([[-0.0303128621945506], [-0.164311501204854], [0.992797338297209]])
#
# Iteration: 2
# x = Matrix([[-0.0303128621945506], [-0.164311501204854], [0.992797338297209]])
# fx = Matrix([[0.266743706827656], [-0.507702657308533], [0.0974700578860670]])
# J = Matrix([[43.9368235860933, -21.7951501377480, 2.95944271800637], [-21.7951501377480, 37.2926007501304, -5.54766057970606], [2.93812685327979, -5.50770265730853, 35.7450000085302]])
# H = Matrix([[22.4665332842001, -21.7951501377480, 2.95944271800637], [-21.7951501377480, 39.8621765541591, 10.0622227414587], [2.95944271800637, 10.0622227414587, 73.8400000000000]])
# xn = Matrix([[-0.0292377058281042], [-0.148412302320317], [0.992912121650875]])
#
# Iteration: 3
# x = Matrix([[-0.0292377058281042], [-0.148412302320317], [0.992912121650875]])
# fx = Matrix([[-0.0325510675475269], [0.0618411375712036], [0.0215118614177641]])
# J = Matrix([[43.9812158587162, -21.8388333661023, 2.63369323150669], [-21.8388333661023, 37.3769739889625, -4.97340978597212], [2.61502593427286, -4.93815886242880, 35.6728424796613]])
# H = Matrix([[22.4864103679227, -21.8388333661023, 2.63369323150669], [-21.8388333661023, 39.7001069171184, 10.6756494651382], [2.63369323150669, 10.6756494651382, 73.8400000000000]])
# xn = Matrix([[-0.0294121291547038], [-0.150584341758919], [0.991705061070593]])
#
# Iteration: 4
# x = Matrix([[-0.0294121291547038], [-0.150584341758919], [0.991705061070593]])
# fx = Matrix([[0.00397509755109038], [-0.00942591201631426], [-0.0111562374984295]])
# J = Matrix([[43.9492926139933, -21.8070234107381, 2.67762497314239], [-21.8070234107381, 37.3211982649082, -5.05132635564893], [2.65541423751432, -5.00942591201631, 35.5941369824255]])
# H = Matrix([[22.4584625507013, -21.8070234107381, 2.67762497314239], [-21.8070234107381, 39.6752099394102, 10.5926140286240], [2.67762497314239, 10.5926140286240, 73.8400000000000]])
# xn = Matrix([[-0.0293412181329198], [-0.150172423450712], [0.992183142055951]])
#
# Iteration: 5
# x = Matrix([[-0.0293412181329198], [-0.150172423450712], [0.992183142055951]])
# fx = Matrix([[-0.000614741411233188], [0.00199309107157575], [0.00399558638967434]])
# J = Matrix([[43.9607561617758, -21.8184408199754, 2.67012626367749], [-21.8184408199754, 37.3410635556806, -5.03738341952859], [2.64925426598165, -4.99800690892842, 35.6275502274827]])
# H = Matrix([[22.4683098273682, -21.8184408199754, 2.67012626367749], [-21.8184408199754, 39.6898161986274, 10.6075334085684], [2.67012626367749, 10.6075334085684, 73.8400000000000]])
# xn = Matrix([[-0.0293660728389567], [-0.150276311746598], [0.992021483528083]])
#
# Iteration: 6
# x = Matrix([[-0.0293660728389567], [-0.150276311746598], [0.992021483528083]])
# fx = Matrix([[0.000127369839674429], [-0.000529016811077199], [-0.00130948008741072]])
# J = Matrix([[43.9569756631720, -21.8146764805140, 2.67186423054470], [-21.8146764805140, 37.3345260300914, -5.04074669736678], [2.65054671777057, -5.00052901681108, 35.6160704748653]])
# H = Matrix([[22.4650958284449, -21.8146764805140, 2.67186423054470], [-21.8146764805140, 39.6845083291319, 10.6039241159927], [2.67186423054470, 10.6039241159927, 73.8400000000000]])
# xn = Matrix([[-0.0293579237368141], [-0.150246121085948], [0.992073659689385]])
#
# Iteration: 7
# x = Matrix([[-0.0293579237368141], [-0.150246121085948], [0.992073659689385]])
# fx = Matrix([[-3.36380633889632e-5], [0.000157412003654933], [0.000419566129661320]])
# J = Matrix([[43.9581867430364, -21.8158822607799, 2.67137953326769], [-21.8158822607799, 37.3366190334015, -5.03978967606274], [2.65020526998820, -4.99984258799634, 35.6197927649091]])
# H = Matrix([[22.4661211688315, -21.8158822607799, 2.67137953326769], [-21.8158822607799, 39.6862563514096, 10.6049526482936], [2.67137953326769, 10.6049526482936, 73.8400000000000]])
# xn = Matrix([[-0.0293605333399446], [-0.150255415063125], [0.992057025769618]])
#
# Iteration: 8
# x = Matrix([[-0.0293605333399446], [-0.150255415063125], [0.992057025769618]])
# fx = Matrix([[9.96681186515858e-6], [-4.88264054450127e-5], [-0.000133367496591319]])
# J = Matrix([[43.9578015479865, -21.8154987626709, 2.67152652382284], [-21.8154987626709, 37.3359534641241, -5.04008206839371], [2.65030665748833, -5.00004882640544, 35.6186043858902]])
# H = Matrix([[22.4657954533474, -21.8154987626709, 2.67152652382284], [-21.8154987626709, 39.6856956330412, 10.6046382433371], [2.67152652382284, 10.6046382433371, 73.8400000000000]])
# xn = Matrix([[-0.0293597036713867], [-0.150252498307868], [0.992062305365490]])
#
# Iteration: 9
# x = Matrix([[-0.0293597036713867], [-0.150252498307868], [0.992062305365490]])
# fx = Matrix([[-3.08892047629072e-6], [1.53647022234082e-5], [4.23003742540118e-5]])
# J = Matrix([[43.9579237181014, -21.8156203932627, 2.67148062843386], [-21.8156203932627, 37.3361645461099, -5.03999054117444], [2.65027523098335, -4.99998463529778, 35.6189817471596]])
# H = Matrix([[22.4658987131665, -21.8156203932627, 2.67148062843386], [-21.8156203932627, 39.6858739504244, 10.6047366789867], [2.67148062843386, 10.6047366789867, 73.8400000000000]])
# xn = Matrix([[-0.0293599668075571], [-0.150253419605040], [0.992060631669689]])
#
# ERROR CRITERIA MET AFTER 9 ITERATIONS
#
# Final Results:
# Theta 2 = -0.0293599668075571 rad | Theta 3 = -0.150253419605040 rad | Voltage 3 = 0.992060631669689 p.u.
# Percent Error:
# Theta 2: 18.7341939750142% | Theta 3: 2.06044595247978% | Voltage 3: 1.42732150799397%

# %%
plt.subplot(2,2,1,title='Theta 2',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(MNR_iteration,MNR_theta2)
plt.subplot(2,2,2,title='Theta 3',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(MNR_iteration,MNR_theta3)
plt.subplot(2,2,3,title='Voltage 3',xlabel='Iteration',ylabel='Voltage (p.u.)')
plt.plot(MNR_iteration,MNR_voltage3)
plt.subplot(2,2,4,title='Error',xlabel='Iteration',ylabel='Error')
plt.plot(MNR_iteration,MNR_t2error,MNR_iteration,MNR_t3error,MNR_iteration,MNR_v3error)
plt.legend(['Theta 2','Theta 3','Voltage 3'],loc=1)
plt.tight_layout()

# %% [markdown]
# ## Power Flow Analysis Using Fast Decoupled Load Flow

# %%
# plot arrays
FDLF_iteration = []
FDLF_theta2 = []
FDLF_theta3 = []
FDLF_voltage3 = []
FDLF_t2error = []
FDLF_t3error = []
FDLF_v3error = []
# admittance matrix, B', and B''
Y = np.array([[-36.92,21.097,15.823],[21.097,-42.194,21.097],[15.823,21.097,-36.92]])
Bp = np.array([[-42.194,21.097],[21.097,-36.92]])
Bpp = -36.92
# known variables
v1 = 1
t1 = 0
v2 = 1.05
p2 = 2
p3 = -5
q3 = -1
# unknown variables / initial guesses
t2 = 0
t3 = 0
v3 = 1
FDLF_iteration.append(0)
FDLF_theta2.append(t2)
FDLF_theta3.append(t3)
FDLF_voltage3.append(v3)
FDLF_t2error.append(1)
FDLF_t3error.append(1)
FDLF_v3error.append(1)
# parameters
max_iter = 10
threshold = 0.0001
i = 0
done = False

# perform FDLF analysis
while not done:
    i += 1
    # calculated values
    p2c = (v2*v1*Y[1,0]*sin(t2-t1))+(v2*v3*Y[1,2]*sin(t2-t3))
    p3c = (v3*v1*Y[2,0]*sin(t3-t1))+(v3*v2*Y[2,1]*sin(t3-t2))
    q3c = (-Y[2,2]*(v3**2))-(v3*v1*Y[2,0]*cos(t3-t1))-(v3*v2*Y[2,1]*cos(t3-t2))
    # print(f"p2c: {p2c} | p3c: {p3c} | q3c: {q3c}")
    # power mismatch
    dp2 = p2 - p2c
    dp3 = p3 - p3c
    dq3 = q3 - q3c
    # print(f"dp2: {dp2} | dp3: {dp3} | dq3 {dq3}")
    # update unknown angles
    angles = np.array([[t2],[t3]])
    angles = angles - np.dot(np.linalg.inv(Bp),np.array([[dp2/v2],[dp3/v3]]))
    # print(f"angles: {angles}")
    t2 = angles[0,0]
    t3 = angles[1,0]
    # print(f"d2: {t2} | d3 {t3}")
    # update unknown voltages
    v3 = v3 - ((-25/923)*(dq3/v3))
    # print(f"v3: {v3}\n\n")
    # update plot arrays and update i
    FDLF_iteration.append(i)
    FDLF_theta2.append(t2)
    FDLF_theta3.append(t3)
    FDLF_voltage3.append(v3)
    FDLF_t2error.append(dp2)
    FDLF_t3error.append(dp3)
    FDLF_v3error.append(dq3)
    # print results each iteration
    print(f"\nIteration: {i}\nUnknowns: d2: {t2} | d3: {t3} | v3: {v3}\nKnowns: p2c: {p2c} | p3c: {p3c} | q3c: {q3c}")
    # check threshold
    if (abs(dp2)<threshold) and (abs(dp3)<threshold) and (abs(dq3)<threshold):
        print(f"\nERROR CRITERIA MET AFTER {i} ITERATIONS")
        done = True
    if i >= max_iter:
        break
print(f"\nFinal Results:\nTheta 2 = {t2} rad | Theta 3 = {t3} rad | Voltage 3 = {v3} p.u.")
print(f"Percent Error:\nTheta 2: {PCE(t2,theta2_true)}% | Theta 3: {PCE(t3,theta3_true)}% | Voltage 3: {PCE(v3,voltage3_true)}%")
# Out:
# Iteration: 1
# Unknowns: d2: -0.0315993420015630 | d3: -0.153484596917849 | v3: 1.00148564463705
# Knowns: p2c: 0 | p3c: 0 | q3c: -1.05485000000000
#
# Iteration: 2
# Unknowns: d2: -0.0292472881245420 | d3: -0.148896164628094 | v3: 0.992036381194355
# Knowns: p2c: 1.99743757446642 | p3c: -5.11996159541584 | q3c: -0.650614901595748
#
# Iteration: 3
# Unknowns: d2: -0.0293899096732862 | d3: -0.150297403980373 | v3: 0.992236606761317
# Knowns: p2c: 1.97527861836331 | p3c: -4.95166315621932 | q3c: -1.00733345825049
#
# Iteration: 4
# Unknowns: d2: -0.0293575854454589 | d3: -0.150227588362042 | v3: 0.992062001581438
# Knowns: p2c: 2.00011446221253 | p3c: -5.00188093173038 | q3c: -0.993603622877494
#
# Iteration: 5
# Unknowns: d2: -0.0293604466190347 | d3: -0.150253815277286 | v3: 0.992064389033781
# Knowns: p2c: 1.99954578588332 | p3c: -4.99909927165897 | q3c: -1.00008744504770
#
# Iteration: 6
# Unknowns: d2: -0.0293598637589708 | d3: -0.150252715030069 | v3: 0.992061081788902
# Knowns: p2c: 1.99999854965390 | p3c: -5.00002809975604 | q3c: -0.999878865484757
#
# Iteration: 7
# Unknowns: d2: -0.0293599134901759 | d3: -0.150253205740690 | v3: 0.992061098792569
# Knowns: p2c: 1.99999133312831 | p3c: -4.99998306764340 | q3c: -1.00000062279155
#
# ERROR CRITERIA MET AFTER 7 ITERATIONS
#
# Final Results:
# Theta 2 = -0.0293599134901759 rad | Theta 3 = -0.150253205740690 rad | Voltage 3 = 0.992061098792569 p.u.
# Percent Error:
# Theta 2: 18.7343415528361% | Theta 3: 2.06058535549037% | Voltage 3: 1.42736926618638%

# %%
plt.subplot(2,2,1,title='Theta 2',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(FDLF_iteration,FDLF_theta2)
plt.subplot(2,2,2,title='Theta 3',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(FDLF_iteration,FDLF_theta3)
plt.subplot(2,2,3,title='Voltage 3',xlabel='Iteration',ylabel='Voltage (p.u.)')
plt.plot(FDLF_iteration,FDLF_voltage3)
plt.subplot(2,2,4,title='Error',xlabel='Iteration',ylabel='Error')
plt.plot(FDLF_iteration,FDLF_t2error,FDLF_iteration,FDLF_t3error,FDLF_iteration,FDLF_v3error)
plt.legend(['Theta 2','Theta 3','Voltage 3'],loc=4)
plt.tight_layout()

# %% [markdown]
# ## Power Flow Analysis Using Gauss-Seidel Method

# %%
# plot arrays
GS_iteration = []
GS_theta2 = []
GS_theta3 = []
GS_voltage3 = []
GS_t2error = []
GS_t3error = []
GS_v3error = []
# admittance matrix
Y = np.array([[-36.92j, 21.097j, 15.823j],[21.097j, -42.194j, 21.097j],[15.823j, 21.097j, -36.92j]])
# known values
v1 = 1.0
t1 = 0.0
v2 = 1.05
p2 = 2.0
p3 = -5.0
q3 = -1.0
# initial guesses
v = np.array([v1, v2, 0.99])
t = np.array([t1, -0.1, -0.1])
GS_iteration.append(0)
GS_theta2.append(t[1])
GS_theta3.append(t[2])
GS_voltage3.append(v[2])
GS_t2error.append(1)
GS_t3error.append(1)
GS_v3error.append(1)
# parameters
max_iter = 1000
threshold = 0.0001
damping_factor = 0.001
damping_factor_min = 0.0000001
done = False
i=0

# perform G-S analysis
while not done:
    i += 1
    # save previous values for damping
    v_prev = np.copy(v)
    t_prev = np.copy(t)
    # update bus 2 values
    p2c = v[1]*(v[0]*Y[1,0].imag*np.sin(t[1]-t[0])+v[2]*Y[1,2].imag*np.sin(t[1]-t[2]))-2
    dv2 = (p2 - p2c)/(v[1]*Y[1,1].imag)
    v[1] += damping_factor*dv2
    t[1] += damping_factor*np.angle(dv2)
    # update bus 3 values
    p3c = v[2]*(v[0]*Y[2,0].imag*np.sin(t[2]-t[0])+v[1]*Y[2,1].imag*np.sin(t[2]-t[1]))+5
    q3c = -1*(v[2]**2)*Y[2,2].imag-v[2]*(v[0]*Y[2,0].imag*np.cos(t[2]-t[0]) + v[1]*Y[2,1].imag*np.cos(t[2]-t[1]))+1
    dv3 = complex(p3 - p3c, q3 - q3c) / (v[2] * Y[2, 2].imag)
    v[2] += damping_factor * dv3.real
    t[2] += damping_factor * np.angle(dv3)
    GS_iteration.append(i)
    GS_theta2.append(t[1])
    GS_theta3.append(t[2])
    GS_voltage3.append(v2)
    GS_t2error.append(PCE(t[1],theta2_true))
    GS_t3error.append(PCE(t[2],theta3_true))
    GS_v3error.append(PCE(v[2],voltage3_true))
    # decrease damping factor
    damping_factor = max(damping_factor * 0.95, damping_factor_min)
    # print each iteration
    # print(f"\nIteration: {i}\nUnknowns: d2: {t[1]} | d3: {t[2]} | v3: {v[2]}")
    # check threshold
    if np.all(np.abs(v-v_prev)<threshold) and np.all(np.abs(t-t_prev)<threshold):
        print(f"\nERROR CRITERIA MET AFTER {i} ITERATIONS")
        done = True
    if i >= max_iter:
        print(f"FAILED TO CONVERGE AFTER {i} ITERATIONS")
        break
print(f"\nFinal Results:\nTheta 2 = {t[1]} rad | Theta 3 = {t[2]} rad | Voltage 3 = {v[2]} p.u.")
print(f"Percent Error:\nTheta 2: {PCE(t[1],theta2_true)}% | Theta 3: {PCE(t[2],theta3_true)}% | Voltage 3: {PCE(v[2],voltage3_true)}%")
# Out:
# ERROR CRITERIA MET AFTER 69 ITERATIONS
#
# Final Results:
# Theta 2 = -0.03899249891210036 rad | Theta 3 = -0.09805176003683914 rad | Voltage 3 = 0.9941240795035821 p.u.
# Percent Error:
# Theta 2: 7.927807745497804% | Theta 3: 36.08700769123557% | Voltage 3: 1.6382864230223997%

# %%
plt.subplot(2,2,1,title='Theta 2',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(GS_iteration,GS_theta2)
plt.subplot(2,2,2,title='Theta 3',xlabel='Iteration',ylabel='Angle (rad)')
plt.plot(GS_iteration,GS_theta3)
plt.subplot(2,2,3,title='Voltage 3',xlabel='Iteration',ylabel='Voltage (p.u.)')
plt.plot(GS_iteration,GS_voltage3)
plt.subplot(2,2,4,title='Percent Error',xlabel='Iteration',ylabel='Error')
plt.plot(GS_iteration,GS_t2error,GS_iteration,GS_t3error,GS_iteration,GS_v3error)
plt.legend(['Theta 2','Theta 3','Voltage 3'],loc=1)
plt.tight_layout()
